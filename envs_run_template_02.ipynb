# %%
import numpy as np
import torch
from env.env_naive_torus import NaiveSandbox
from patterns.gliders import gliders 

import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 10, 20

# %%
sandbox = NaiveSandbox(grid_size=(100,100))

# %%
agents_action = torch.tensor(gliders['glider'])
x = 0
y = 0

# %%
agents_action
# Out:
# tensor([[0, 0, 1],
#         [1, 0, 1],
#         [0, 1, 1]])

# %%
grid = sandbox.forward(inserted_block=agents_action, inserted_block_position_x0=x, inserted_block_position_y0=y)

# %%
plt.imshow(grid)

# %%
sandbox.insert_block(gliders['gosper_glider_gun'], 50, 50)

# %%
sandbox.step(40)
plt.imshow(sandbox.get_grid())
